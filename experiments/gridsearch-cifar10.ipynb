# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import glob
from tqdm import tqdm
import json
import numpy as np
from report import read_dfs, index_dfs
from report import generate_bar_chart, generate_bar_chart_overlay
from report import report_gridsearch
from report import read_accs
from report import cifar10_files as files

np.set_printoptions(suppress=True, linewidth=np.inf)
plt.rcParams.update({'font.size': 6})

logdir = 'results/gridsearch-cifar10'
attacks = ['jpeg', 'elastic', 'wood', 'glitch', 'kaleidoscope', 'pixel', 'snow', 'gabor']

# %% [markdown]
# # Core attacks

# %% [markdown]
# ## Low distortion

# %%
distortion = 'low'
attack_stepsize = {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
attack_steps = {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=f'UA2_cifar10_bar_{distortion}.pdf', \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
# {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}

# %% [markdown]
# ## Medium distortion

# %%
distortion = 'medium'
attack_stepsize = {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
attack_steps = {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=f'UA2_cifar10_bar_{distortion}.pdf', \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
# {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}

# %% [markdown]
# ## High distortion

# %%
distortion = 'high'
attack_stepsize = {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
attack_steps = {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=f'UA2_cifar10_bar_{distortion}.pdf', \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# {'jpeg': 0.0024, 'elastic': 0.006, 'wood': 0.000625, 'glitch': 0.0025, 'kaleidoscope': 0.005, 'pixel': 1.0, 'snow': 0.2, 'gabor': 0.0025}
# {'jpeg': 50, 'elastic': 30, 'wood': 70, 'glitch': 60, 'kaleidoscope': 30, 'pixel': 60, 'snow': 20, 'gabor': 80}

# %% [markdown]
# # Extra attacks

# %%
attacks = "edge fbm fog hsv klotski mix polkadot prison blur texture whirlpool".split()

# %% [markdown]
# ## Low distortion

# %%
distortion = 'low'
attack_stepsize = None
attack_steps = None
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=None, \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# NAN in file results/gridsearch-cifar10/cifar10_l2_wrn28-10.pt-blur-low.jsonl
# [(0.00375, 70)]
# {'edge': 0.005, 'fbm': 0.003, 'fog': 0.025, 'hsv': 0.0015, 'klotski': 0.0025, 'mix': 0.125, 'polkadot': 0.3, 'prison': 0.000375, 'blur': 0.00375, 'texture': 0.000375, 'whirlpool': 4.0}
# {'edge': 20, 'fbm': 10, 'fog': 10, 'hsv': 10, 'klotski': 30, 'mix': 10, 'polkadot': 10, 'prison': 20, 'blur': 10, 'texture': 10, 'whirlpool': 10}

# %% [markdown]
# ## Medium distortion

# %%
distortion = 'medium'
attack_stepsize = None
attack_steps = None
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=f'UA2_cifar10_bar_{distortion}.pdf', \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# {'edge': 0.02, 'fbm': 0.006, 'fog': 0.05, 'hsv': 0.003, 'klotski': 0.005, 'mix': 0.5, 'polkadot': 0.3, 'prison': 0.0015, 'blur': 0.015, 'texture': 0.003, 'whirlpool': 16.0}
# {'edge': 20, 'fbm': 20, 'fog': 20, 'hsv': 20, 'klotski': 40, 'mix': 10, 'polkadot': 30, 'prison': 20, 'blur': 10, 'texture': 30, 'whirlpool': 30}

# %% [markdown]
# ## High distortion

# %%
distortion = 'high'
attack_stepsize = None
attack_steps = None
key_dfs_fixed, key_dfs_optimal, attack_stepsize2, attack_steps2 = \
                report_gridsearch(attacks, 'cifar10', logdir, epsilon=distortion, \
                               attack_stepsize=attack_stepsize, attack_steps=attack_steps)
generate_bar_chart_overlay(key_dfs_fixed, key_dfs_optimal, \
                           file_name=f'UA2_cifar10_bar_{distortion}.pdf', \
                           figsize=(10, 3), xlim=100, yticks_padding=150, plot_height=0.95)
print(attack_stepsize2)
print(attack_steps2)
# Out:
# {'edge': 0.08, 'fbm': 0.012, 'fog': 0.05, 'hsv': 0.006, 'klotski': 0.01, 'mix': 1.0, 'polkadot': 0.6, 'prison': 0.006, 'blur': 0.03, 'texture': 0.006, 'whirlpool': 16.0}
# {'edge': 60, 'fbm': 30, 'fog': 40, 'hsv': 20, 'klotski': 50, 'mix': 30, 'polkadot': 40, 'prison': 20, 'blur': 20, 'texture': 30, 'whirlpool': 50}
